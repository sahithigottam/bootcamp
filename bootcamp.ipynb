# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics 
import warnings

# %%
filename = "/Users/sahithi/Desktop/auto-mpg.csv"

# %%
df = pd.read_csv(filename)

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df.tail()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin         car name
# 393          82       1  ford mustang gl
# 394          82       2        vw pickup
# 395          82       1    dodge rampage
# 396          82       1      ford ranger
# 397          82       1       chevy s-10

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df.shape
# Out:
# (398, 9)

# %%
df.shape[0]
# Out:
# 398

# %%
df.shape[1]
# Out:
# 9

# %%
df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'origin', 'car name'],
#       dtype='object')

# %%
calls = df.columns

# %%
calls
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'origin', 'car name'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=398, step=1)

# %%
df.sort_values(by = "mpg")
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 28    9.0          8         304.0        193    4732          18.5
# 25   10.0          8         360.0        215    4615          14.0
# 26   10.0          8         307.0        200    4376          15.0
# 103  11.0          8         400.0        150    4997          14.0
# 124  11.0          8         350.0        180    3664          11.0
# ..    ...        ...           ...        ...     ...           ...
# 326  43.4          4          90.0         48    2335          23.7
# 394  44.0          4          97.0         52    2130          24.6
# 325  44.3          4          90.0         48    2085          21.7
# 329  44.6          4          91.0         67    1850          13.8
# 322  46.6          4          86.0         65    2110          17.9
#
#      model year  origin              car name
# 28           70       1              hi 1200d
# 25           70       1             ford f250
# ...

# %%
df.sort_values(by = "mpg",ascending=True)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 28    9.0          8         304.0        193    4732          18.5
# 25   10.0          8         360.0        215    4615          14.0
# 26   10.0          8         307.0        200    4376          15.0
# 103  11.0          8         400.0        150    4997          14.0
# 124  11.0          8         350.0        180    3664          11.0
# ..    ...        ...           ...        ...     ...           ...
# 326  43.4          4          90.0         48    2335          23.7
# 394  44.0          4          97.0         52    2130          24.6
# 325  44.3          4          90.0         48    2085          21.7
# 329  44.6          4          91.0         67    1850          13.8
# 322  46.6          4          86.0         65    2110          17.9
#
#      model year  origin              car name
# 28           70       1              hi 1200d
# 25           70       1             ford f250
# ...

# %%
df.sort_values(by = ["mpg","cylinders"],ascending=True)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 28    9.0          8         304.0        193    4732          18.5
# 25   10.0          8         360.0        215    4615          14.0
# 26   10.0          8         307.0        200    4376          15.0
# 27   11.0          8         318.0        210    4382          13.5
# 67   11.0          8         429.0        208    4633          11.0
# ..    ...        ...           ...        ...     ...           ...
# 326  43.4          4          90.0         48    2335          23.7
# 394  44.0          4          97.0         52    2130          24.6
# 325  44.3          4          90.0         48    2085          21.7
# 329  44.6          4          91.0         67    1850          13.8
# 322  46.6          4          86.0         65    2110          17.9
#
#      model year  origin              car name
# 28           70       1              hi 1200d
# 25           70       1             ford f250
# ...

# %%
df.sort_values(by = ["mpg","cylinders"],ascending=[True,False])
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 28    9.0          8         304.0        193    4732          18.5
# 25   10.0          8         360.0        215    4615          14.0
# 26   10.0          8         307.0        200    4376          15.0
# 27   11.0          8         318.0        210    4382          13.5
# 67   11.0          8         429.0        208    4633          11.0
# ..    ...        ...           ...        ...     ...           ...
# 326  43.4          4          90.0         48    2335          23.7
# 394  44.0          4          97.0         52    2130          24.6
# 325  44.3          4          90.0         48    2085          21.7
# 329  44.6          4          91.0         67    1850          13.8
# 322  46.6          4          86.0         65    2110          17.9
#
#      model year  origin              car name
# 28           70       1              hi 1200d
# 25           70       1             ford f250
# ...

# %%
df.mpg
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
df["mpg"]
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
df[["mpg","horsepower","weight"]]
# Out:
#       mpg horsepower  weight
# 0    18.0        130    3504
# 1    15.0        165    3693
# 2    18.0        150    3436
# 3    16.0        150    3433
# 4    17.0        140    3449
# ..    ...        ...     ...
# 393  27.0         86    2790
# 394  44.0         52    2130
# 395  32.0         84    2295
# 396  28.0         79    2625
# 397  31.0         82    2720
#
# [398 rows x 3 columns]

# %%
class1 = df["mpg"]>30

# %%
class1
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 393    False
# 394     True
# 395     True
# 396    False
# 397     True
# Name: mpg, Length: 398, dtype: bool

# %% [markdown]
# # boolean indexing

# %%
df[class1]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 53   31.0          4          71.0         65    1773          19.0
# 54   35.0          4          72.0         69    1613          18.0
# 129  31.0          4          79.0         67    1950          19.0
# 131  32.0          4          71.0         65    1836          21.0
# 144  31.0          4          76.0         52    1649          16.5
# ..    ...        ...           ...        ...     ...           ...
# 390  32.0          4         144.0         96    2665          13.9
# 391  36.0          4         135.0         84    2370          13.0
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin             car name
# 53           71       3  toyota corolla 1200
# 54           71       3          datsun 1200
# ...

# %%
df["mpg"]>30
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 393    False
# 394     True
# 395     True
# 396    False
# 397     True
# Name: mpg, Length: 398, dtype: bool

# %%
df["displacement"]>150
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 393    False
# 394    False
# 395    False
# 396    False
# 397    False
# Name: displacement, Length: 398, dtype: bool

# %%
mask1 = df["cylinder"]==3
mask2 = df["cylinder"]==4

# %%
mask1
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 393    True
# 394    True
# 395    True
# 396    True
# 397    True
# Name: cylinder, Length: 398, dtype: bool

# %%
mask2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 393    False
# 394    False
# 395    False
# 396    False
# 397    False
# Name: cylinder, Length: 398, dtype: bool

# %%
df[(mask1)|(mask2)]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name  cylinder
# 0            70       1  chevrolet chevelle malibu         3
# ...

# %%
mask3 = df["cylinder"].isin([3,4])

# %%
df["weight"]/1000
# Out:
# 0      3.504
# 1      3.693
# 2      3.436
# 3      3.433
# 4      3.449
#        ...
# 393    2.790
# 394    2.130
# 395    2.295
# 396    2.625
# 397    2.720
# Name: weight, Length: 398, dtype: float64

# %%
df["mpg"].min()
# Out:
# 9.0

# %%
df["mpg"].max()
# Out:
# 46.6

# %%
df["mpg"].mean()
# Out:
# 23.514572864321615

# %%
df["mpg"].var()
# Out:
# 61.089610774274405

# %%
df["mpg"].quantile(0.25)
# Out:
# 17.5

# %%
df["mpg"].quantile([0.75,0.25,0.5,0.995])
# Out:
# 0.750    29.0000
# 0.250    17.5000
# 0.500    23.0000
# 0.995    44.3045
# Name: mpg, dtype: float64

# %%
df.describe(include="object")
# Out:
#        horsepower    car name
# count         398         398
# unique         94         305
# top           150  ford pinto
# freq           22           6

# %%
df["cylinders"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      8
# 1      8
# 2      8
# 3      8
# 4      8
#       ..
# 393    4
# 394    4
# 395    4
# 396    4
# 397    4
# Name: cylinders, Length: 398, dtype: int64>

# %%
df["cylinders"].unique()
# Out:
# array([8, 4, 6, 3, 5])

# %%
df["cylinders"].nunique()
# Out:
# 5

# %%
df.loc[:,:]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name  cylinder
# 0            70       1  chevrolet chevelle malibu         3
# ...

# %%
df.loc[:,"mpg"]
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
df.loc[2,"mpg"]
# Out:
# 18.0

# %%
df.loc[2:10,"mpg"]
# Out:
# 2     18.0
# 3     16.0
# 4     17.0
# 5     15.0
# 6     14.0
# 7     14.0
# 8     14.0
# 9     15.0
# 10    15.0
# Name: mpg, dtype: float64

# %%
df.loc[2:10,"mpg":"origin"]
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  \
# 2   18.0          8         318.0        150    3436          11.0
# 3   16.0          8         304.0        150    3433          12.0
# 4   17.0          8         302.0        140    3449          10.5
# 5   15.0          8         429.0        198    4341          10.0
# 6   14.0          8         454.0        220    4354           9.0
# 7   14.0          8         440.0        215    4312           8.5
# 8   14.0          8         455.0        225    4425          10.0
# 9   15.0          8         390.0        190    3850           8.5
# 10  15.0          8         383.0        170    3563          10.0
#
#     model year  origin
# 2           70       1
# 3           70       1
# 4           70       1
# 5           70       1
# 6           70       1
# 7           70       1
# 8           70       1
# 9           70       1
# 10          70       1

# %%
df.loc[2:10,["mpg","origin"]]
# Out:
#      mpg  origin
# 2   18.0       1
# 3   16.0       1
# 4   17.0       1
# 5   15.0       1
# 6   14.0       1
# 7   14.0       1
# 8   14.0       1
# 9   15.0       1
# 10  15.0       1

# %%
df.loc[[250,270],["mpg","origin"]]
# Out:
#       mpg  origin
# 250  19.4       1
# 270  21.1       3

# %%
df.iloc[[250,270],[0,4,7]]

# %% [markdown]
# iloc is used when bwe give all numbers. its easy to give column indexes rather than typing the entire columun . iloc is zero based indexing

# %%
df.drop_duplicates()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name  cylinder
# 0            70       1  chevrolet chevelle malibu         3
# ...

# %%
df.drop_duplicates(subset= "mpg")
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# 6    14.0          8         454.0        220    4354           9.0
# ..    ...        ...           ...        ...     ...           ...
# 362  24.2          6         146.0        120    2930          13.8
# 363  22.4          6         231.0        110    3415          15.8
# 369  34.0          4         112.0         88    2395          18.0
# 378  38.0          4         105.0         63    2125          14.7
# 394  44.0          4          97.0         52    2130          24.6
#
#      model year  origin                   car name  cylinder
# 0            70       1  chevrolet chevelle malibu         3
# ...

# %%
df.drop_duplicates(subset=["mpg","weight"])
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name  cylinder
# 0            70       1  chevrolet chevelle malibu         3
# ...

# %%
df.drop_duplicates(subset= "cylinders")
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 14   24.0          4         113.0         95    2372          15.0
# 15   22.0          6         198.0         95    2833          15.5
# 71   19.0          3          70.0         97    2330          13.5
# 274  20.3          5         131.0        103    2830          15.9
#
#      model year  origin                   car name  cylinder
# 0            70       1  chevrolet chevelle malibu         3
# 14           70       3      toyota corona mark ii         3
# 15           70       1            plymouth duster         3
# 71           72       3            mazda rx2 coupe         3
# 274          78       2                  audi 5000         3

# %%
df.sample(100)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 268  27.2          4         119.0         97    2300          14.7
# 245  36.1          4          98.0         66    1800          14.4
# 252  19.2          6         231.0        105    3535          19.2
# 185  26.0          4          98.0         79    2255          17.7
# 370  31.0          4         112.0         85    2575          16.2
# ..    ...        ...           ...        ...     ...           ...
# 233  29.0          4          97.0         78    1940          14.5
# 324  40.8          4          85.0         65    2110          19.2
# 243  21.5          3          80.0        110    2720          13.5
# 297  25.4          5         183.0         77    3530          20.1
# 23   26.0          4         121.0        113    2234          12.5
#
#      model year  origin                    car name  cylinder
# 268          78       3                  datsun 510         3
# ...

# %%
df.sample(frac=0.25)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 181  33.0          4          91.0         53    1795          17.5
# 210  19.0          6         156.0        108    2930          15.5
# 71   19.0          3          70.0         97    2330          13.5
# 147  24.0          4          90.0         75    2108          15.5
# 63   14.0          8         400.0        175    4385          12.0
# ..    ...        ...           ...        ...     ...           ...
# 253  20.5          6         200.0         95    3155          18.2
# 39   14.0          8         400.0        175    4464          11.5
# 236  25.5          4         140.0         89    2755          15.8
# 123  20.0          6         156.0        122    2807          13.5
# 297  25.4          5         183.0         77    3530          20.1
#
#      model year  origin                   car name  cylinder
# 181          75       3           honda civic cvcc         3
# ...

# %%
df.sample(frac=0.25,random_state= 3)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 358  31.6          4         120.0         74    2635          18.3
# 16   18.0          6         199.0         97    2774          15.5
# 292  18.5          8         360.0        150    3940          13.0
# 81   28.0          4          97.0         92    2288          17.0
# 112  19.0          4         122.0         85    2310          18.5
# ..    ...        ...           ...        ...     ...           ...
# 80   22.0          4         122.0         86    2395          16.0
# 105  13.0          8         360.0        170    4654          13.0
# 255  25.1          4         140.0         88    2720          15.4
# 5    15.0          8         429.0        198    4341          10.0
# 75   14.0          8         318.0        150    4077          14.0
#
#      model year  origin                              car name  cylinder
# 358          81       3                             mazda 626         3
# ...

# %%
df.sample(frac=0.25,random_state= 3,replace=True)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 362  24.2          6         146.0        120    2930          13.8
# 152  19.0          6         225.0         95    3264          16.0
# 249  19.9          8         260.0        110    3365          15.5
# 131  32.0          4          71.0         65    1836          21.0
# 256  20.5          6         225.0        100    3430          17.2
# ..    ...        ...           ...        ...     ...           ...
# 216  31.5          4          98.0         68    2045          18.5
# 311  32.1          4          98.0         70    2120          15.5
# 267  27.5          4         134.0         95    2560          14.2
# 212  16.5          8         350.0        180    4380          12.1
# 394  44.0          4          97.0         52    2130          24.6
#
#      model year  origin                           car name  cylinder
# 362          81       3                  datsun 810 maxima         3
# ...

# %%
from sklearn.neighbours
# Out:
#   Input In [166]
#     from sklearn.neighbours
#                            ^
# SyntaxError: invalid syntax

# %%
df["cylinders"].value_counts()/len(df)
# Out:
# 4    0.512563
# 8    0.258794
# 6    0.211055
# 3    0.010050
# 5    0.007538
# Name: cylinders, dtype: float64

# %%
df["cylinders"].value_counts()/len(df)*100
# Out:
# 4    51.256281
# 8    25.879397
# 6    21.105528
# 3     1.005025
# 5     0.753769
# Name: cylinders, dtype: float64

# %%
df["cylinders"].value_counts()/df.shape[0]
# Out:
# 4    0.512563
# 8    0.258794
# 6    0.211055
# 3    0.010050
# 5    0.007538
# Name: cylinders, dtype: float64

# %%
df["cylinders"].value_counts(normalize=True)*100
# Out:
# 4    51.256281
# 8    25.879397
# 6    21.105528
# 3     1.005025
# 5     0.753769
# Name: cylinders, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg
# Out:
# LinearRegression()

# %%
df.groupby(['cylinders'])['weight','mpg'].mean()
# Out:
# /var/folders/fj/q35yrt4d19g2nw3g9mdzw2980000gp/T/ipykernel_77707/1472372881.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['cylinders'])['weight','mpg'].mean()
#                 weight        mpg
# cylinders
# 3          2398.500000  20.550000
# 4          2308.127451  29.286765
# 5          3103.333333  27.366667
# 6          3198.226190  19.985714
# 8          4114.718447  14.963107

# %%
df.groupby(['cylinders'])['weight','mpg'].min()
# Out:
# /var/folders/fj/q35yrt4d19g2nw3g9mdzw2980000gp/T/ipykernel_77707/262485518.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['cylinders'])['weight','mpg'].min()
#            weight   mpg
# cylinders
# 3            2124  18.0
# 4            1613  18.0
# 5            2830  20.3
# 6            2472  15.0
# 8            3086   9.0

# %%
df.groupby(['cylinders'])['weight','mpg'].max()
# Out:
# /var/folders/fj/q35yrt4d19g2nw3g9mdzw2980000gp/T/ipykernel_77707/780372117.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['cylinders'])['weight','mpg'].max()
#            weight   mpg
# cylinders
# 3            2720  23.7
# 4            3270  46.6
# 5            3530  36.4
# 6            3907  38.0
# 8            5140  26.6

# %%
warnings.filterwarnings("ignore")

# %%
df.groupby(['cylinders'])['weight','mpg'].agg([min,max])
# Out:
#           weight         mpg
#              min   max   min   max
# cylinders
# 3           2124  2720  18.0  23.7
# 4           1613  3270  18.0  46.6
# 5           2830  3530  20.3  36.4
# 6           2472  3907  15.0  38.0
# 8           3086  5140   9.0  26.6

# %%
df.groupby(['origin','cylinders'])['weight','mpg'].agg([min,max,sum])
# Out:
#                  weight                 mpg
#                     min   max     sum   min   max     sum
# origin cylinders
# 1      4           1800  3035  175476  19.0  39.0  2004.5
#        6           2472  3907  237829  15.0  38.0  1455.1
#        8           3086  5140  423816   9.0  26.6  1541.2
# 2      4           1825  3270  146791  18.0  44.3  1789.9
#        5           2830  3530    9310  20.3  36.4    82.1
#        6           3140  3820   13530  16.2  30.7    80.4
# 3      3           2124  2720    9594  18.0  23.7    82.2
#        4           1613  2711  148591  20.0  46.6  2180.1
#        6           2807  2930   17292  19.0  32.7   143.3

# %%
dict = {'Name':['Anju', 'Ajithra', 'jayaram', 'Georgia'],
        'Maths':[87, 91, 97, 95],
        'Science':[83, 99, 84, 76]
       }

# %%
df2 = pd.DataFrame(dict)

# %%
df2.loc[4] = ['Sahithi', 89, 93]

# %%
df2
# Out:
#       Name  Maths  Science
# 0     Anju     87       83
# 1  Ajithra     91       99
# 2  jayaram     97       84
# 3  Georgia     95       76
# 4  Sahithi     89       93

# %%
n = 50
for i in range(1,n//2):
    if n%i  == 0:
        print("not prime")
        break
    else:
        print("prime")
# Out:
# not prime

# %%
def factorial(n):
    if n == 1:
        return 1
    
    fact_n = factorial(n-1) * n
    
    return fact_n

n = int(input())
k = factorial(n)
print(k)
# Out:
# 5
# 120

# %%
num in range (20,50):
    for i in range(2,num):
        if (num%i)==0,
            break
    else:
        print(num)
# Out:
#   Input In [214]
#     num in range (20,50):
#                          ^
# SyntaxError: invalid syntax
